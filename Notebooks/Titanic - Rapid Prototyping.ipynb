# %% [markdown]
# # Rapid prototyping - Titanic

# %% [markdown]
# ## Package loading

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
gender_sub = pd.read_csv("gender_submission.csv")

# %% [markdown]
# ## Basic Exploratory Data Analysis

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ## Rapid Prototyping

# %% [markdown]
# The goal with rapid prototyping is to prove that a specific project or concept is possible in the fastest, most efficient way possible. We want to answer the question:
#
#
# <p style="text-align: center;"><strong>Can we get a working prototype?</strong></p>
#
#
# If we can't, then we know we don't have to waste effort on an unsolvable problem. If we can solve the problem then we can work on a much deeper analysis.

# %% [markdown]
# For the purpose of rapid prototyping, lets impute data in the most simplest way or drop it if we need to.

# %%
# Fill the age with the median value

median_age_train = train.Age.median()

# Fill missing Age, forward fill embarked, drop what we may not need for rapid prototyping
train.Age.fillna(median_age_train, inplace=True)
train.Embarked.fillna(method='ffill', inplace=True)
train.drop(['Name', 'Cabin', 'Ticket'], axis=1, inplace=True)

median_age_test = test.Age.median() # set median value

# fill NAN data
test.Age.fillna(median_age_test, inplace=True)
test.drop(['Name', 'Cabin', 'Ticket'], axis=1, inplace=True)

# %% [markdown]
# ### Deep Feature Synthesis
#
# Part of the goal of a working prototype would be to create features that can help out prototype do good work without too much work or understanding of the domain initially.
#
# While the Titanic problem is simple enough to understand, when confronted with more difficult problems where features aren't well understood. This can be very valuable.

# %%
import featuretools as ft

# %%
full = train.append(test)
passenger_id=test['PassengerId']
# Out:
# /anaconda3/envs/fastai-cpu/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
# replace missing Fare
full.Fare.fillna(full.Fare.mean(), inplace=True)

# Encode Gender
full['Sex'] = full.Sex.apply(lambda x: 0 if x == "female" else 1)

# Encode Embarked
full['Embarked'] = full['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

# replace all other missing with 0
full.fillna(0, inplace=True)

# %%
# We create an entity set
es = ft.EntitySet(id = 'titanic')

# %%
es = es.entity_from_dataframe(entity_id = 'full', dataframe = full.drop(['Survived'], axis=1), 
                              variable_types = 
                              {
                                  'Embarked': ft.variable_types.Categorical,
                                  'Sex': ft.variable_types.Boolean
                              },
                              index = 'PassengerId')

es
# Out:
# Entityset: titanic
#   Entities:
#     full [Rows: 1309, Columns: 8]
#   Relationships:
#     No relationships

# %%
es = es.normalize_entity(base_entity_id='full', new_entity_id='Embarked', index='Embarked')
es = es.normalize_entity(base_entity_id='full', new_entity_id='Sex', index='Sex')
es = es.normalize_entity(base_entity_id='full', new_entity_id='Pclass', index='Pclass')
es = es.normalize_entity(base_entity_id='full', new_entity_id='Parch', index='Parch')
es = es.normalize_entity(base_entity_id='full', new_entity_id='SibSp', index='SibSp')
es
# Out:
# Entityset: titanic
#   Entities:
#     full [Rows: 1309, Columns: 8]
#     Embarked [Rows: 3, Columns: 1]
#     Sex [Rows: 2, Columns: 1]
#     Pclass [Rows: 3, Columns: 1]
#     Parch [Rows: 8, Columns: 1]
#     SibSp [Rows: 7, Columns: 1]
#   Relationships:
#     full.Embarked -> Embarked.Embarked
#     full.Sex -> Sex.Sex
#     full.Pclass -> Pclass.Pclass
#     full.Parch -> Parch.Parch
#     full.SibSp -> SibSp.SibSp

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation'].head(primitives[primitives['type'] == 'aggregation'].shape[0])
# Out:
#                 name         type  \
# 0           num_true  aggregation
# 1                std  aggregation
# 2                sum  aggregation
# 3              count  aggregation
# 4         num_unique  aggregation
# 5               skew  aggregation
# 6    time_since_last  aggregation
# 7   time_since_first  aggregation
# 8                max  aggregation
# 9             median  aggregation
# 10  avg_time_between  aggregation
# 11               all  aggregation
# 12             trend  aggregation
# 13               min  aggregation
# 14               any  aggregation
# 15     n_most_common  aggregation
# 16      percent_true  aggregation
# 17              mode  aggregation
# 18              last  aggregation
# 19              mean  aggregation
#
#                                                                         description
# 0                                               Counts the number of `True` values.
# 1               Computes the dispersion relative to the mean value, ignoring `NaN`.
# 2                                    Calculates the total addition, ignoring `NaN`.
# 3                           Determines the total number of values, excluding `NaN`.
# 4                  Determines the number of distinct values, ignoring `NaN` values.
# 5   Computes the extent to which a distribution differs from a normal distribution.
# 6                 Calculates the time elapsed since the last datetime (in seconds).
# 7                Calculates the time elapsed since the first datetime (in seconds).
# 8                              Calculates the highest value, ignoring `NaN` values.
# 9                             Determines the middlemost number in a list of values.
# 10               Computes the average number of seconds between consecutive events.
# 11                                   Calculates if all values are 'True' in a list.
# 12                                    Calculates the trend of a variable over time.
# 13                            Calculates the smallest value, ignoring `NaN` values.
# 14                                     Determines if any value is 'True' in a list.
# 15                                         Determines the `n` most common elements.
# 16                                         Determines the percent of `True` values.
# 17                                     Determines the most commonly repeated value.
# 18                                             Determines the last value in a list.
# 19                                       Computes the average for a list of values.

# %%
primitives[primitives['type'] == 'transform'].head(primitives[primitives['type'] == 'transform'].shape[0])
# Out:
#                                name       type  \
# 20                        haversine  transform
# 21          multiply_numeric_scalar  transform
# 22        less_than_equal_to_scalar  transform
# 23                modulo_by_feature  transform
# 24                   num_characters  transform
# 25              time_since_previous  transform
# 26                          is_null  transform
# 27                               or  transform
# 28                         latitude  transform
# 29  scalar_subtract_numeric_feature  transform
# 30                       is_weekend  transform
# 31                 less_than_scalar  transform
# 32                   modulo_numeric  transform
# 33                              not  transform
# 34                 subtract_numeric  transform
# 35            divide_numeric_scalar  transform
# 36     greater_than_equal_to_scalar  transform
# 37                            month  transform
# 38                          cum_max  transform
# 39                      add_numeric  transform
# 40                             diff  transform
# 41              greater_than_scalar  transform
# 42                           minute  transform
# 43                         cum_mean  transform
# 44                       days_since  transform
# 45                        not_equal  transform
# 46                             hour  transform
# 47                          cum_sum  transform
# 48                   divide_numeric  transform
# 49                              and  transform
# 50                            equal  transform
# 51                        num_words  transform
# 52                       time_since  transform
# 53                        longitude  transform
# 54                         absolute  transform
# 55               less_than_equal_to  transform
# 56            modulo_numeric_scalar  transform
# 57                 multiply_numeric  transform
# 58                          weekday  transform
# 59                       percentile  transform
# 60          subtract_numeric_scalar  transform
# 61                divide_by_feature  transform
# 62                        less_than  transform
# 63                             year  transform
# 64               add_numeric_scalar  transform
# 65                           negate  transform
# 66            greater_than_equal_to  transform
# 67                             week  transform
# 68                          cum_min  transform
# 69                             isin  transform
# 70                 not_equal_scalar  transform
# 71                     greater_than  transform
# 72                           second  transform
# 73                        cum_count  transform
# 74                     equal_scalar  transform
# 75                              day  transform
#
#                                                                     description
# 20            Calculates the approximate haversine distance between two LatLong
# 21                               Multiply each element in the list by a scalar.
# 22               Determines if values are less than or equal to a given scalar.
# 23                   Return the modulo of a scalar by each element in the list.
# 24                             Calculates the number of characters in a string.
# 25         Compute the time in seconds since the previous instance of an entry.
# 26                                               Determines if a value is null.
# 27                                        Element-wise logical OR of two lists.
# 28                   Returns the first tuple value in a list of LatLong tuples.
# 29                         Subtract each value in the list from a given scalar.
# 30                                     Determines if a date falls on a weekend.
# 31                           Determines if values are less than a given scalar.
# 32                                            Element-wise modulo of two lists.
# 33                                                     Negates a boolean value.
# 34                                       Element-wise subtraction of two lists.
# 35                                 Divide each element in the list by a scalar.
# 36            Determines if values are greater than or equal to a given scalar.
# 37                                    Determines the month value of a datetime.
# 38                                           Calculates the cumulative maximum.
# 39                                          Element-wise addition of two lists.
# 40                   Compute the difference between the value in a list and the
# 41                        Determines if values are greater than a given scalar.
# 42                                  Determines the minutes value of a datetime.
# 43                                              Calculates the cumulative mean.
# 44          Calculates the number of days from a value to a specified datetime.
# 45              Determines if values in one list are not equal to another list.
# 46                                     Determines the hour value of a datetime.
# 47                                               Calculates the cumulative sum.
# 48                                          Element-wise division of two lists.
# 49                                       Element-wise logical AND of two lists.
# 50                  Determines if values in one list are equal to another list.
# 51           Determines the number of words in a string by counting the spaces.
# 52  Calculates time in nanoseconds from a value to a specified cutoff datetime.
# 53                  Returns the second tuple value in a list of LatLong tuples.
# 54                                     Computes the absolute value of a number.
# 55     Determines if values in one list are less than or equal to another list.
# 56                   Return the modulo of each element in the list by a scalar.
# 57                                    Element-wise multiplication of two lists.
# 58                              Determines the day of the week from a datetime.
# 59                     Determines the percentile rank for each value in a list.
# 60                             Subtract a scalar from each element in the list.
# 61                                   Divide a scalar by each value in the list.
# 62                 Determines if values in one list are less than another list.
# 63                                     Determines the year value of a datetime.
# 64                                      Add a scalar to each value in the list.
# 65                                                     Negates a numeric value.
# 66  Determines if values in one list are greater than or equal to another list.
# 67                             Determines the week of the year from a datetime.
# 68                                           Calculates the cumulative minimum.
# 69                    Determines whether a value is present in a provided list.
# 70              Determines if values in a list are not equal to a given scalar.
# 71              Determines if values in one list are greater than another list.
# 72                                  Determines the seconds value of a datetime.
# 73                                             Calculates the cumulative count.
# 74                  Determines if values in a list are equal to a given scalar.
# 75                             Determines the day of the month from a datetime.

# %%
features, feature_names = ft.dfs(entityset = es, 
                                 target_entity = 'full', 
                                 max_depth = 2)

# %%
feature_names
# Out:
# [<Feature: Age>,
#  <Feature: Fare>,
#  <Feature: Parch>,
#  <Feature: Pclass>,
#  <Feature: SibSp>,
#  <Feature: Embarked>,
#  <Feature: Sex>,
#  <Feature: Embarked.SUM(full.Age)>,
#  <Feature: Embarked.SUM(full.Fare)>,
#  <Feature: Embarked.STD(full.Age)>,
#  <Feature: Embarked.STD(full.Fare)>,
#  <Feature: Embarked.MAX(full.Age)>,
#  <Feature: Embarked.MAX(full.Fare)>,
#  <Feature: Embarked.SKEW(full.Age)>,
#  <Feature: Embarked.SKEW(full.Fare)>,
#  <Feature: Embarked.MIN(full.Age)>,
#  <Feature: Embarked.MIN(full.Fare)>,
#  <Feature: Embarked.MEAN(full.Age)>,
#  <Feature: Embarked.MEAN(full.Fare)>,
#  <Feature: Embarked.COUNT(full)>,
#  <Feature: Embarked.NUM_UNIQUE(full.Parch)>,
#  <Feature: Embarked.NUM_UNIQUE(full.Pclass)>,
#  <Feature: Embarked.NUM_UNIQUE(full.SibSp)>,
#  <Feature: Embarked.NUM_UNIQUE(full.Sex)>,
#  <Feature: Embarked.MODE(full.Parch)>,
#  <Feature: Embarked.MODE(full.Pclass)>,
#  <Feature: Embarked.MODE(full.SibSp)>,
#  <Feature: Embarked.MODE(full.Sex)>,
#  <Feature: Sex.SUM(full.Age)>,
#  <Feature: Sex.SUM(full.Fare)>,
#  <Feature: Sex.STD(full.Age)>,
#  <Feature: Sex.STD(full.Fare)>,
#  <Feature: Sex.MAX(full.Age)>,
#  <Feature: Sex.MAX(full.Fare)>,
#  <Feature: Sex.SKEW(full.Age)>,
#  <Feature: Sex.SKEW(full.Fare)>,
#  <Feature: Sex.MIN(full.Age)>,
#  <Feature: Sex.MIN(full.Fare)>,
#  <Feature: Sex.MEAN(full.Age)>,
#  <Feature: Sex.MEAN(full.Fare)>,
#  <Feature: Sex.COUNT(full)>,
#  <Feature: Sex.NUM_UNIQUE(full.Parch)>,
#  <Feature: Sex.NUM_UNIQUE(full.Pclass)>,
#  <Feature: Sex.NUM_UNIQUE(full.SibSp)>,
#  <Feature: Sex.NUM_UNIQUE(full.Embarked)>,
#  <Feature: Sex.MODE(full.Parch)>,
#  <Feature: Sex.MODE(full.Pclass)>,
#  <Feature: Sex.MODE(full.SibSp)>,
#  <Feature: Sex.MODE(full.Embarked)>,
#  <Feature: Pclass.SUM(full.Age)>,
#  <Feature: Pclass.SUM(full.Fare)>,
#  <Feature: Pclass.STD(full.Age)>,
#  <Feature: Pclass.STD(full.Fare)>,
#  <Feature: Pclass.MAX(full.Age)>,
#  <Feature: Pclass.MAX(full.Fare)>,
#  <Feature: Pclass.SKEW(full.Age)>,
#  <Feature: Pclass.SKEW(full.Fare)>,
#  <Feature: Pclass.MIN(full.Age)>,
#  <Feature: Pclass.MIN(full.Fare)>,
#  <Feature: Pclass.MEAN(full.Age)>,
#  <Feature: Pclass.MEAN(full.Fare)>,
#  <Feature: Pclass.COUNT(full)>,
#  <Feature: Pclass.NUM_UNIQUE(full.Parch)>,
#  <Feature: Pclass.NUM_UNIQUE(full.SibSp)>,
#  <Feature: Pclass.NUM_UNIQUE(full.Embarked)>,
#  <Feature: Pclass.NUM_UNIQUE(full.Sex)>,
#  <Feature: Pclass.MODE(full.Parch)>,
#  <Feature: Pclass.MODE(full.SibSp)>,
#  <Feature: Pclass.MODE(full.Embarked)>,
#  <Feature: Pclass.MODE(full.Sex)>,
#  <Feature: Parch.SUM(full.Age)>,
#  <Feature: Parch.SUM(full.Fare)>,
#  <Feature: Parch.STD(full.Age)>,
#  <Feature: Parch.STD(full.Fare)>,
#  <Feature: Parch.MAX(full.Age)>,
#  <Feature: Parch.MAX(full.Fare)>,
#  <Feature: Parch.SKEW(full.Age)>,
#  <Feature: Parch.SKEW(full.Fare)>,
#  <Feature: Parch.MIN(full.Age)>,
#  <Feature: Parch.MIN(full.Fare)>,
#  <Feature: Parch.MEAN(full.Age)>,
#  <Feature: Parch.MEAN(full.Fare)>,
#  <Feature: Parch.COUNT(full)>,
#  <Feature: Parch.NUM_UNIQUE(full.Pclass)>,
#  <Feature: Parch.NUM_UNIQUE(full.SibSp)>,
#  <Feature: Parch.NUM_UNIQUE(full.Embarked)>,
#  <Feature: Parch.NUM_UNIQUE(full.Sex)>,
#  <Feature: Parch.MODE(full.Pclass)>,
#  <Feature: Parch.MODE(full.SibSp)>,
#  <Feature: Parch.MODE(full.Embarked)>,
#  <Feature: Parch.MODE(full.Sex)>,
#  <Feature: SibSp.SUM(full.Age)>,
#  <Feature: SibSp.SUM(full.Fare)>,
#  <Feature: SibSp.STD(full.Age)>,
#  <Feature: SibSp.STD(full.Fare)>,
#  <Feature: SibSp.MAX(full.Age)>,
#  <Feature: SibSp.MAX(full.Fare)>,
#  <Feature: SibSp.SKEW(full.Age)>,
#  <Feature: SibSp.SKEW(full.Fare)>,
#  <Feature: SibSp.MIN(full.Age)>,
#  <Feature: SibSp.MIN(full.Fare)>,
#  <Feature: SibSp.MEAN(full.Age)>,
#  <Feature: SibSp.MEAN(full.Fare)>,
#  <Feature: SibSp.COUNT(full)>,
#  <Feature: SibSp.NUM_UNIQUE(full.Parch)>,
#  <Feature: SibSp.NUM_UNIQUE(full.Pclass)>,
#  <Feature: SibSp.NUM_UNIQUE(full.Embarked)>,
#  <Feature: SibSp.NUM_UNIQUE(full.Sex)>,
#  <Feature: SibSp.MODE(full.Parch)>,
#  <Feature: SibSp.MODE(full.Pclass)>,
#  <Feature: SibSp.MODE(full.Embarked)>,
#  <Feature: SibSp.MODE(full.Sex)>]

# %%
len(feature_names)
# Out:
# 112

# %% [markdown]
# In a few minutes we've generated a bunch of features that we can use for prototyping our problem

# %%
# Threshold for removing correlated variables
threshold = 0.95

# Absolute value correlation matrix
corr_matrix = features.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper.head(50)
# Out:
#                                   Age      Fare     Parch    Pclass     SibSp  \
# Age                               NaN  0.180519  0.125677  0.380274  0.188920
# Fare                              NaN       NaN  0.221522  0.558477  0.160224
# Parch                             NaN       NaN       NaN  0.018322  0.373587
# Pclass                            NaN       NaN       NaN       NaN  0.060832
# SibSp                             NaN       NaN       NaN       NaN       NaN
# Embarked                          NaN       NaN       NaN       NaN       NaN
# Sex                               NaN       NaN       NaN       NaN       NaN
# Embarked.SUM(full.Age)            NaN       NaN       NaN       NaN       NaN
# Embarked.SUM(full.Fare)           NaN       NaN       NaN       NaN       NaN
# Embarked.STD(full.Age)            NaN       NaN       NaN       NaN       NaN
# Embarked.STD(full.Fare)           NaN       NaN       NaN       NaN       NaN
# Embarked.MAX(full.Age)            NaN       NaN       NaN       NaN       NaN
# Embarked.MAX(full.Fare)           NaN       NaN       NaN       NaN       NaN
# Embarked.SKEW(full.Age)           NaN       NaN       NaN       NaN       NaN
# Embarked.SKEW(full.Fare)          NaN       NaN       NaN       NaN       NaN
# Embarked.MIN(full.Age)            NaN       NaN       NaN       NaN       NaN
# Embarked.MIN(full.Fare)           NaN       NaN       NaN       NaN       NaN
# Embarked.MEAN(full.Age)           NaN       NaN       NaN       NaN       NaN
# Embarked.MEAN(full.Fare)          NaN       NaN       NaN       NaN       NaN
# Embarked.COUNT(full)              NaN       NaN       NaN       NaN       NaN
# Embarked.NUM_UNIQUE(full.Parch)   NaN       NaN       NaN       NaN       NaN
# Embarked.NUM_UNIQUE(full.Pclass)  NaN       NaN       NaN       NaN       NaN
# Embarked.NUM_UNIQUE(full.SibSp)   NaN       NaN       NaN       NaN       NaN
# Embarked.NUM_UNIQUE(full.Sex)     NaN       NaN       NaN       NaN       NaN
# Embarked.MODE(full.Parch)         NaN       NaN       NaN       NaN       NaN
# Embarked.MODE(full.Pclass)        NaN       NaN       NaN       NaN       NaN
# Embarked.MODE(full.SibSp)         NaN       NaN       NaN       NaN       NaN
# Embarked.MODE(full.Sex)           NaN       NaN       NaN       NaN       NaN
# Sex.SUM(full.Age)                 NaN       NaN       NaN       NaN       NaN
# Sex.SUM(full.Fare)                NaN       NaN       NaN       NaN       NaN
# Sex.STD(full.Age)                 NaN       NaN       NaN       NaN       NaN
# Sex.STD(full.Fare)                NaN       NaN       NaN       NaN       NaN
# Sex.MAX(full.Age)                 NaN       NaN       NaN       NaN       NaN
# Sex.MAX(full.Fare)                NaN       NaN       NaN       NaN       NaN
# Sex.SKEW(full.Age)                NaN       NaN       NaN       NaN       NaN
# Sex.SKEW(full.Fare)               NaN       NaN       NaN       NaN       NaN
# Sex.MIN(full.Age)                 NaN       NaN       NaN       NaN       NaN
# Sex.MIN(full.Fare)                NaN       NaN       NaN       NaN       NaN
# Sex.MEAN(full.Age)                NaN       NaN       NaN       NaN       NaN
# Sex.MEAN(full.Fare)               NaN       NaN       NaN       NaN       NaN
# Sex.COUNT(full)                   NaN       NaN       NaN       NaN       NaN
# Sex.NUM_UNIQUE(full.Parch)        NaN       NaN       NaN       NaN       NaN
# Sex.NUM_UNIQUE(full.Pclass)       NaN       NaN       NaN       NaN       NaN
# Sex.NUM_UNIQUE(full.SibSp)        NaN       NaN       NaN       NaN       NaN
# Sex.NUM_UNIQUE(full.Embarked)     NaN       NaN       NaN       NaN       NaN
# Sex.MODE(full.Parch)              NaN       NaN       NaN       NaN       NaN
# Sex.MODE(full.Pclass)             NaN       NaN       NaN       NaN       NaN
# Sex.MODE(full.SibSp)              NaN       NaN       NaN       NaN       NaN
# Sex.MODE(full.Embarked)           NaN       NaN       NaN       NaN       NaN
# Pclass.SUM(full.Age)              NaN       NaN       NaN       NaN       NaN
#
#                                   Embarked       Sex  Embarked.SUM(full.Age)  \
# Age                               0.022174  0.052928                0.040441
# Fare                              0.064135  0.185484                0.136867
# Parch                             0.096857  0.213125                0.083092
# Pclass                            0.033373  0.124617                0.051522
# SibSp                             0.074966  0.109609                0.076507
# Embarked                               NaN  0.124849                0.966496
# Sex                                    NaN       NaN                0.123637
# Embarked.SUM(full.Age)                 NaN       NaN                     NaN
# Embarked.SUM(full.Fare)                NaN       NaN                     NaN
# Embarked.STD(full.Age)                 NaN       NaN                     NaN
# Embarked.STD(full.Fare)                NaN       NaN                     NaN
# Embarked.MAX(full.Age)                 NaN       NaN                     NaN
# Embarked.MAX(full.Fare)                NaN       NaN                     NaN
# Embarked.SKEW(full.Age)                NaN       NaN                     NaN
# Embarked.SKEW(full.Fare)               NaN       NaN                     NaN
# Embarked.MIN(full.Age)                 NaN       NaN                     NaN
# Embarked.MIN(full.Fare)                NaN       NaN                     NaN
# Embarked.MEAN(full.Age)                NaN       NaN                     NaN
# Embarked.MEAN(full.Fare)               NaN       NaN                     NaN
# Embarked.COUNT(full)                   NaN       NaN                     NaN
# Embarked.NUM_UNIQUE(full.Parch)        NaN       NaN                     NaN
# Embarked.NUM_UNIQUE(full.Pclass)       NaN       NaN                     NaN
# Embarked.NUM_UNIQUE(full.SibSp)        NaN       NaN                     NaN
# Embarked.NUM_UNIQUE(full.Sex)          NaN       NaN                     NaN
# Embarked.MODE(full.Parch)              NaN       NaN                     NaN
# Embarked.MODE(full.Pclass)             NaN       NaN                     NaN
# Embarked.MODE(full.SibSp)              NaN       NaN                     NaN
# Embarked.MODE(full.Sex)                NaN       NaN                     NaN
# Sex.SUM(full.Age)                      NaN       NaN                     NaN
# Sex.SUM(full.Fare)                     NaN       NaN                     NaN
# Sex.STD(full.Age)                      NaN       NaN                     NaN
# Sex.STD(full.Fare)                     NaN       NaN                     NaN
# Sex.MAX(full.Age)                      NaN       NaN                     NaN
# Sex.MAX(full.Fare)                     NaN       NaN                     NaN
# Sex.SKEW(full.Age)                     NaN       NaN                     NaN
# Sex.SKEW(full.Fare)                    NaN       NaN                     NaN
# Sex.MIN(full.Age)                      NaN       NaN                     NaN
# Sex.MIN(full.Fare)                     NaN       NaN                     NaN
# Sex.MEAN(full.Age)                     NaN       NaN                     NaN
# Sex.MEAN(full.Fare)                    NaN       NaN                     NaN
# Sex.COUNT(full)                        NaN       NaN                     NaN
# Sex.NUM_UNIQUE(full.Parch)             NaN       NaN                     NaN
# Sex.NUM_UNIQUE(full.Pclass)            NaN       NaN                     NaN
# Sex.NUM_UNIQUE(full.SibSp)             NaN       NaN                     NaN
# Sex.NUM_UNIQUE(full.Embarked)          NaN       NaN                     NaN
# Sex.MODE(full.Parch)                   NaN       NaN                     NaN
# Sex.MODE(full.Pclass)                  NaN       NaN                     NaN
# Sex.MODE(full.SibSp)                   NaN       NaN                     NaN
# Sex.MODE(full.Embarked)                NaN       NaN                     NaN
# Pclass.SUM(full.Age)                   NaN       NaN                     NaN
#
#                                   Embarked.SUM(full.Fare)  \
# Age                                              0.008514
# Fare                                             0.010706
# Parch                                            0.102642
# Pclass                                           0.091441
# SibSp                                            0.070912
# Embarked                                         0.983744
# Sex                                              0.120740
# Embarked.SUM(full.Age)                           0.904692
# Embarked.SUM(full.Fare)                               NaN
# Embarked.STD(full.Age)                                NaN
# Embarked.STD(full.Fare)                               NaN
# Embarked.MAX(full.Age)                                NaN
# Embarked.MAX(full.Fare)                               NaN
# Embarked.SKEW(full.Age)                               NaN
# Embarked.SKEW(full.Fare)                              NaN
# Embarked.MIN(full.Age)                                NaN
# Embarked.MIN(full.Fare)                               NaN
# Embarked.MEAN(full.Age)                               NaN
# Embarked.MEAN(full.Fare)                              NaN
# Embarked.COUNT(full)                                  NaN
# Embarked.NUM_UNIQUE(full.Parch)                       NaN
# Embarked.NUM_UNIQUE(full.Pclass)                      NaN
# Embarked.NUM_UNIQUE(full.SibSp)                       NaN
# Embarked.NUM_UNIQUE(full.Sex)                         NaN
# Embarked.MODE(full.Parch)                             NaN
# Embarked.MODE(full.Pclass)                            NaN
# Embarked.MODE(full.SibSp)                             NaN
# Embarked.MODE(full.Sex)                               NaN
# Sex.SUM(full.Age)                                     NaN
# Sex.SUM(full.Fare)                                    NaN
# Sex.STD(full.Age)                                     NaN
# Sex.STD(full.Fare)                                    NaN
# Sex.MAX(full.Age)                                     NaN
# Sex.MAX(full.Fare)                                    NaN
# Sex.SKEW(full.Age)                                    NaN
# Sex.SKEW(full.Fare)                                   NaN
# Sex.MIN(full.Age)                                     NaN
# Sex.MIN(full.Fare)                                    NaN
# Sex.MEAN(full.Age)                                    NaN
# Sex.MEAN(full.Fare)                                   NaN
# Sex.COUNT(full)                                       NaN
# Sex.NUM_UNIQUE(full.Parch)                            NaN
# Sex.NUM_UNIQUE(full.Pclass)                           NaN
# Sex.NUM_UNIQUE(full.SibSp)                            NaN
# Sex.NUM_UNIQUE(full.Embarked)                         NaN
# Sex.MODE(full.Parch)                                  NaN
# Sex.MODE(full.Pclass)                                 NaN
# Sex.MODE(full.SibSp)                                  NaN
# Sex.MODE(full.Embarked)                               NaN
# Pclass.SUM(full.Age)                                  NaN
#
#                                   Embarked.STD(full.Age)  ...  \
# Age                                             0.045555  ...
# Fare                                            0.193481  ...
# Parch                                           0.091228  ...
# Pclass                                          0.280068  ...
# SibSp                                           0.032782  ...
# Embarked                                        0.604985  ...
# Sex                                             0.066315  ...
# Embarked.SUM(full.Age)                          0.380337  ...
# Embarked.SUM(full.Fare)                         0.738135  ...
# Embarked.STD(full.Age)                               NaN  ...
# Embarked.STD(full.Fare)                              NaN  ...
# Embarked.MAX(full.Age)                               NaN  ...
# Embarked.MAX(full.Fare)                              NaN  ...
# Embarked.SKEW(full.Age)                              NaN  ...
# Embarked.SKEW(full.Fare)                             NaN  ...
# Embarked.MIN(full.Age)                               NaN  ...
# Embarked.MIN(full.Fare)                              NaN  ...
# Embarked.MEAN(full.Age)                              NaN  ...
# Embarked.MEAN(full.Fare)                             NaN  ...
# Embarked.COUNT(full)                                 NaN  ...
# Embarked.NUM_UNIQUE(full.Parch)                      NaN  ...
# Embarked.NUM_UNIQUE(full.Pclass)                     NaN  ...
# Embarked.NUM_UNIQUE(full.SibSp)                      NaN  ...
# Embarked.NUM_UNIQUE(full.Sex)                        NaN  ...
# Embarked.MODE(full.Parch)                            NaN  ...
# Embarked.MODE(full.Pclass)                           NaN  ...
# Embarked.MODE(full.SibSp)                            NaN  ...
# Embarked.MODE(full.Sex)                              NaN  ...
# Sex.SUM(full.Age)                                    NaN  ...
# Sex.SUM(full.Fare)                                   NaN  ...
# Sex.STD(full.Age)                                    NaN  ...
# Sex.STD(full.Fare)                                   NaN  ...
# Sex.MAX(full.Age)                                    NaN  ...
# Sex.MAX(full.Fare)                                   NaN  ...
# Sex.SKEW(full.Age)                                   NaN  ...
# Sex.SKEW(full.Fare)                                  NaN  ...
# Sex.MIN(full.Age)                                    NaN  ...
# Sex.MIN(full.Fare)                                   NaN  ...
# Sex.MEAN(full.Age)                                   NaN  ...
# Sex.MEAN(full.Fare)                                  NaN  ...
# Sex.COUNT(full)                                      NaN  ...
# Sex.NUM_UNIQUE(full.Parch)                           NaN  ...
# Sex.NUM_UNIQUE(full.Pclass)                          NaN  ...
# Sex.NUM_UNIQUE(full.SibSp)                           NaN  ...
# Sex.NUM_UNIQUE(full.Embarked)                        NaN  ...
# Sex.MODE(full.Parch)                                 NaN  ...
# Sex.MODE(full.Pclass)                                NaN  ...
# Sex.MODE(full.SibSp)                                 NaN  ...
# Sex.MODE(full.Embarked)                              NaN  ...
# Pclass.SUM(full.Age)                                 NaN  ...
#
#                                   SibSp.MEAN(full.Fare)  SibSp.COUNT(full)  \
# Age                                        6.079957e-02       1.308523e-01
# Fare                                       2.256391e-01       2.089606e-01
# Parch                                      3.302803e-01       3.625643e-01
# Pclass                                     9.321064e-02       5.610448e-02
# SibSp                                      7.100906e-01       8.101948e-01
# Embarked                                   7.474154e-02       5.931944e-02
# Sex                                        1.925157e-01       1.773133e-01
# Embarked.SUM(full.Age)                     5.080938e-02       4.266879e-02
# Embarked.SUM(full.Fare)                    8.851772e-02       6.861361e-02
# Embarked.STD(full.Age)                     1.116884e-01       8.137341e-02
# Embarked.STD(full.Fare)                    6.863038e-02       4.548945e-02
# Embarked.MAX(full.Age)                     3.953760e-02       3.467741e-02
# Embarked.MAX(full.Fare)                    7.869541e-02       5.334542e-02
# Embarked.SKEW(full.Age)                    1.117975e-01       8.235227e-02
# Embarked.SKEW(full.Fare)                   8.041969e-02       5.470374e-02
# Embarked.MIN(full.Age)                     1.042943e-01       7.866970e-02
# Embarked.MIN(full.Fare)                    6.626721e-02       5.348169e-02
# Embarked.MEAN(full.Age)                    5.853642e-02       3.771210e-02
# Embarked.MEAN(full.Fare)                   6.548557e-02       4.305673e-02
# Embarked.COUNT(full)                       4.855874e-02       4.107968e-02
# Embarked.NUM_UNIQUE(full.Parch)            3.634142e-02       3.239726e-02
# Embarked.NUM_UNIQUE(full.Pclass)                    NaN                NaN
# Embarked.NUM_UNIQUE(full.SibSp)            2.014379e-02       2.075504e-02
# Embarked.NUM_UNIQUE(full.Sex)                       NaN                NaN
# Embarked.MODE(full.Parch)                           NaN                NaN
# Embarked.MODE(full.Pclass)                 3.844424e-02       2.245797e-02
# Embarked.MODE(full.SibSp)                           NaN                NaN
# Embarked.MODE(full.Sex)                             NaN                NaN
# Sex.SUM(full.Age)                          1.925157e-01       1.773133e-01
# Sex.SUM(full.Fare)                         1.925157e-01       1.773133e-01
# Sex.STD(full.Age)                          1.925157e-01       1.773133e-01
# Sex.STD(full.Fare)                         1.925157e-01       1.773133e-01
# Sex.MAX(full.Age)                          1.925157e-01       1.773133e-01
# Sex.MAX(full.Fare)                         3.665734e-14       2.195949e-16
# Sex.SKEW(full.Age)                         1.925157e-01       1.773133e-01
# Sex.SKEW(full.Fare)                        1.925157e-01       1.773133e-01
# Sex.MIN(full.Age)                          1.925157e-01       1.773133e-01
# Sex.MIN(full.Fare)                         1.925157e-01       1.773133e-01
# Sex.MEAN(full.Age)                         1.925157e-01       1.773133e-01
# Sex.MEAN(full.Fare)                        1.925157e-01       1.773133e-01
# Sex.COUNT(full)                            1.925157e-01       1.773133e-01
# Sex.NUM_UNIQUE(full.Parch)                          NaN                NaN
# Sex.NUM_UNIQUE(full.Pclass)                         NaN                NaN
# Sex.NUM_UNIQUE(full.SibSp)                          NaN                NaN
# Sex.NUM_UNIQUE(full.Embarked)                       NaN                NaN
# Sex.MODE(full.Parch)                                NaN                NaN
# Sex.MODE(full.Pclass)                               NaN                NaN
# Sex.MODE(full.SibSp)                                NaN                NaN
# Sex.MODE(full.Embarked)                             NaN                NaN
# Pclass.SUM(full.Age)                       7.015821e-02       3.925644e-02
#
#                                   SibSp.NUM_UNIQUE(full.Parch)  \
# Age                                               1.976589e-01
# Fare                                              4.979847e-02
# Parch                                             5.262633e-02
# Pclass                                            2.076503e-01
# SibSp                                             4.109176e-01
# Embarked                                          2.727147e-02
# Sex                                               8.506071e-02
# Embarked.SUM(full.Age)                            6.158505e-02
# Embarked.SUM(full.Fare)                           2.182977e-03
# Embarked.STD(full.Age)                            9.277791e-02
# Embarked.STD(full.Fare)                           1.399096e-01
# Embarked.MAX(full.Age)                            7.500714e-02
# Embarked.MAX(full.Fare)                           1.386663e-01
# Embarked.SKEW(full.Age)                           7.634822e-02
# Embarked.SKEW(full.Fare)                          1.382240e-01
# Embarked.MIN(full.Age)                            3.734317e-02
# Embarked.MIN(full.Fare)                           4.049116e-02
# Embarked.MEAN(full.Age)                           1.392973e-01
# Embarked.MEAN(full.Fare)                          1.398962e-01
# Embarked.COUNT(full)                              6.438503e-02
# Embarked.NUM_UNIQUE(full.Parch)                   7.855319e-02
# Embarked.NUM_UNIQUE(full.Pclass)                           NaN
# Embarked.NUM_UNIQUE(full.SibSp)                   9.492864e-02
# Embarked.NUM_UNIQUE(full.Sex)                              NaN
# Embarked.MODE(full.Parch)                                  NaN
# Embarked.MODE(full.Pclass)                        1.339125e-01
# Embarked.MODE(full.SibSp)                                  NaN
# Embarked.MODE(full.Sex)                                    NaN
# Sex.SUM(full.Age)                                 8.506071e-02
# Sex.SUM(full.Fare)                                8.506071e-02
# Sex.STD(full.Age)                                 8.506071e-02
# Sex.STD(full.Fare)                                8.506071e-02
# Sex.MAX(full.Age)                                 8.506071e-02
# Sex.MAX(full.Fare)                                3.351113e-16
# Sex.SKEW(full.Age)                                8.506071e-02
# Sex.SKEW(full.Fare)                               8.506071e-02
# Sex.MIN(full.Age)                                 8.506071e-02
# Sex.MIN(full.Fare)                                8.506071e-02
# Sex.MEAN(full.Age)                                8.506071e-02
# Sex.MEAN(full.Fare)                               8.506071e-02
# Sex.COUNT(full)                                   8.506071e-02
# Sex.NUM_UNIQUE(full.Parch)                                 NaN
# Sex.NUM_UNIQUE(full.Pclass)                                NaN
# Sex.NUM_UNIQUE(full.SibSp)                                 NaN
# Sex.NUM_UNIQUE(full.Embarked)                              NaN
# Sex.MODE(full.Parch)                                       NaN
# Sex.MODE(full.Pclass)                                      NaN
# Sex.MODE(full.SibSp)                                       NaN
# Sex.MODE(full.Embarked)                                    NaN
# Pclass.SUM(full.Age)                              1.914864e-01
#
#                                   SibSp.NUM_UNIQUE(full.Pclass)  \
# Age                                                2.133987e-01
# Fare                                               3.105973e-02
# Parch                                              2.650650e-01
# Pclass                                             1.435907e-01
# SibSp                                              7.593949e-01
# Embarked                                           3.287548e-02
# Sex                                                1.654746e-03
# Embarked.SUM(full.Age)                             5.262555e-02
# Embarked.SUM(full.Fare)                            1.775324e-02
# Embarked.STD(full.Age)                             4.479328e-02
# Embarked.STD(full.Fare)                            8.583273e-02
# Embarked.MAX(full.Age)                             6.000096e-02
# Embarked.MAX(full.Fare)                            8.311418e-02
# Embarked.SKEW(full.Age)                            3.321729e-02
# Embarked.SKEW(full.Fare)                           8.248716e-02
# Embarked.MIN(full.Age)                             7.157385e-03
# Embarked.MIN(full.Fare)                            4.062107e-02
# Embarked.MEAN(full.Age)                            8.725143e-02
# Embarked.MEAN(full.Fare)                           8.639949e-02
# Embarked.COUNT(full)                               5.418260e-02
# Embarked.NUM_UNIQUE(full.Parch)                    6.190952e-02
# Embarked.NUM_UNIQUE(full.Pclass)                            NaN
# Embarked.NUM_UNIQUE(full.SibSp)                    7.045971e-02
# Embarked.NUM_UNIQUE(full.Sex)                               NaN
# Embarked.MODE(full.Parch)                                   NaN
# Embarked.MODE(full.Pclass)                         8.714516e-02
# Embarked.MODE(full.SibSp)                                   NaN
# Embarked.MODE(full.Sex)                                     NaN
# Sex.SUM(full.Age)                                  1.654746e-03
# Sex.SUM(full.Fare)                                 1.654746e-03
# Sex.STD(full.Age)                                  1.654746e-03
# Sex.STD(full.Fare)                                 1.654746e-03
# Sex.MAX(full.Age)                                  1.654746e-03
# Sex.MAX(full.Fare)                                 1.484102e-15
# Sex.SKEW(full.Age)                                 1.654746e-03
# Sex.SKEW(full.Fare)                                1.654746e-03
# Sex.MIN(full.Age)                                  1.654746e-03
# Sex.MIN(full.Fare)                                 1.654746e-03
# Sex.MEAN(full.Age)                                 1.654746e-03
# Sex.MEAN(full.Fare)                                1.654746e-03
# Sex.COUNT(full)                                    1.654746e-03
# Sex.NUM_UNIQUE(full.Parch)                                  NaN
# Sex.NUM_UNIQUE(full.Pclass)                                 NaN
# Sex.NUM_UNIQUE(full.SibSp)                                  NaN
# Sex.NUM_UNIQUE(full.Embarked)                               NaN
# Sex.MODE(full.Parch)                                        NaN
# Sex.MODE(full.Pclass)                                       NaN
# Sex.MODE(full.SibSp)                                        NaN
# Sex.MODE(full.Embarked)                                     NaN
# Pclass.SUM(full.Age)                               1.480807e-01
#
#                                   SibSp.NUM_UNIQUE(full.Embarked)  \
# Age                                                  2.012332e-01
# Fare                                                 9.761043e-02
# Parch                                                2.781161e-01
# Pclass                                               1.240303e-01
# SibSp                                                7.792276e-01
# Embarked                                             8.961550e-02
# Sex                                                  4.743528e-02
# Embarked.SUM(full.Age)                               1.046465e-01
# Embarked.SUM(full.Fare)                              7.554246e-02
# Embarked.STD(full.Age)                               1.724522e-03
# Embarked.STD(full.Fare)                              8.526836e-02
# Embarked.MAX(full.Age)                               1.089434e-01
# Embarked.MAX(full.Fare)                              7.566791e-02
# Embarked.SKEW(full.Age)                              1.505507e-02
# Embarked.SKEW(full.Fare)                             7.379029e-02
# Embarked.MIN(full.Age)                               4.846077e-02
# Embarked.MIN(full.Fare)                              9.602416e-02
# Embarked.MEAN(full.Age)                              9.300786e-02
# Embarked.MEAN(full.Fare)                             8.785982e-02
# Embarked.COUNT(full)                                 1.056263e-01
# Embarked.NUM_UNIQUE(full.Parch)                      1.098979e-01
# Embarked.NUM_UNIQUE(full.Pclass)                              NaN
# Embarked.NUM_UNIQUE(full.SibSp)                      1.131144e-01
# Embarked.NUM_UNIQUE(full.Sex)                                 NaN
# Embarked.MODE(full.Parch)                                     NaN
# Embarked.MODE(full.Pclass)                           1.041817e-01
# Embarked.MODE(full.SibSp)                                     NaN
# Embarked.MODE(full.Sex)                                       NaN
# Sex.SUM(full.Age)                                    4.743528e-02
# Sex.SUM(full.Fare)                                   4.743528e-02
# Sex.STD(full.Age)                                    4.743528e-02
# Sex.STD(full.Fare)                                   4.743528e-02
# Sex.MAX(full.Age)                                    4.743528e-02
# Sex.MAX(full.Fare)                                   2.188883e-15
# Sex.SKEW(full.Age)                                   4.743528e-02
# Sex.SKEW(full.Fare)                                  4.743528e-02
# Sex.MIN(full.Age)                                    4.743528e-02
# Sex.MIN(full.Fare)                                   4.743528e-02
# Sex.MEAN(full.Age)                                   4.743528e-02
# Sex.MEAN(full.Fare)                                  4.743528e-02
# Sex.COUNT(full)                                      4.743528e-02
# Sex.NUM_UNIQUE(full.Parch)                                    NaN
# Sex.NUM_UNIQUE(full.Pclass)                                   NaN
# Sex.NUM_UNIQUE(full.SibSp)                                    NaN
# Sex.NUM_UNIQUE(full.Embarked)                                 NaN
# Sex.MODE(full.Parch)                                          NaN
# Sex.MODE(full.Pclass)                                         NaN
# Sex.MODE(full.SibSp)                                          NaN
# Sex.MODE(full.Embarked)                                       NaN
# Pclass.SUM(full.Age)                                 1.407274e-01
#
#                                   SibSp.NUM_UNIQUE(full.Sex)  \
# Age                                                      NaN
# Fare                                                     NaN
# Parch                                                    NaN
# Pclass                                                   NaN
# SibSp                                                    NaN
# Embarked                                                 NaN
# Sex                                                      NaN
# Embarked.SUM(full.Age)                                   NaN
# Embarked.SUM(full.Fare)                                  NaN
# Embarked.STD(full.Age)                                   NaN
# Embarked.STD(full.Fare)                                  NaN
# Embarked.MAX(full.Age)                                   NaN
# Embarked.MAX(full.Fare)                                  NaN
# Embarked.SKEW(full.Age)                                  NaN
# Embarked.SKEW(full.Fare)                                 NaN
# Embarked.MIN(full.Age)                                   NaN
# Embarked.MIN(full.Fare)                                  NaN
# Embarked.MEAN(full.Age)                                  NaN
# Embarked.MEAN(full.Fare)                                 NaN
# Embarked.COUNT(full)                                     NaN
# Embarked.NUM_UNIQUE(full.Parch)                          NaN
# Embarked.NUM_UNIQUE(full.Pclass)                         NaN
# Embarked.NUM_UNIQUE(full.SibSp)                          NaN
# Embarked.NUM_UNIQUE(full.Sex)                            NaN
# Embarked.MODE(full.Parch)                                NaN
# Embarked.MODE(full.Pclass)                               NaN
# Embarked.MODE(full.SibSp)                                NaN
# Embarked.MODE(full.Sex)                                  NaN
# Sex.SUM(full.Age)                                        NaN
# Sex.SUM(full.Fare)                                       NaN
# Sex.STD(full.Age)                                        NaN
# Sex.STD(full.Fare)                                       NaN
# Sex.MAX(full.Age)                                        NaN
# Sex.MAX(full.Fare)                                       NaN
# Sex.SKEW(full.Age)                                       NaN
# Sex.SKEW(full.Fare)                                      NaN
# Sex.MIN(full.Age)                                        NaN
# Sex.MIN(full.Fare)                                       NaN
# Sex.MEAN(full.Age)                                       NaN
# Sex.MEAN(full.Fare)                                      NaN
# Sex.COUNT(full)                                          NaN
# Sex.NUM_UNIQUE(full.Parch)                               NaN
# Sex.NUM_UNIQUE(full.Pclass)                              NaN
# Sex.NUM_UNIQUE(full.SibSp)                               NaN
# Sex.NUM_UNIQUE(full.Embarked)                            NaN
# Sex.MODE(full.Parch)                                     NaN
# Sex.MODE(full.Pclass)                                    NaN
# Sex.MODE(full.SibSp)                                     NaN
# Sex.MODE(full.Embarked)                                  NaN
# Pclass.SUM(full.Age)                                     NaN
#
#                                   SibSp.MODE(full.Parch)  \
# Age                                         2.379074e-01
# Fare                                        6.134832e-02
# Parch                                       2.938461e-01
# Pclass                                      1.488672e-01
# SibSp                                       8.217369e-01
# Embarked                                    5.740721e-02
# Sex                                         2.062120e-02
# Embarked.SUM(full.Age)                      7.803594e-02
# Embarked.SUM(full.Fare)                     4.069646e-02
# Embarked.STD(full.Age)                      3.522716e-02
# Embarked.STD(full.Fare)                     9.677419e-02
# Embarked.MAX(full.Age)                      8.526941e-02
# Embarked.MAX(full.Fare)                     9.124495e-02
# Embarked.SKEW(full.Age)                     2.028997e-02
# Embarked.SKEW(full.Fare)                    9.008990e-02
# Embarked.MIN(full.Age)                      1.177652e-02
# Embarked.MIN(full.Fare)                     6.568088e-02
# Embarked.MEAN(full.Age)                     1.006344e-01
# Embarked.MEAN(full.Fare)                    9.813762e-02
# Embarked.COUNT(full)                        7.958898e-02
# Embarked.NUM_UNIQUE(full.Parch)             8.708501e-02
# Embarked.NUM_UNIQUE(full.Pclass)                     NaN
# Embarked.NUM_UNIQUE(full.SibSp)             9.484037e-02
# Embarked.NUM_UNIQUE(full.Sex)                        NaN
# Embarked.MODE(full.Parch)                            NaN
# Embarked.MODE(full.Pclass)                  1.045429e-01
# Embarked.MODE(full.SibSp)                            NaN
# Embarked.MODE(full.Sex)                              NaN
# Sex.SUM(full.Age)                           2.062120e-02
# Sex.SUM(full.Fare)                          2.062120e-02
# Sex.STD(full.Age)                           2.062120e-02
# Sex.STD(full.Fare)                          2.062120e-02
# Sex.MAX(full.Age)                           2.062120e-02
# Sex.MAX(full.Fare)                          4.885604e-16
# Sex.SKEW(full.Age)                          2.062120e-02
# Sex.SKEW(full.Fare)                         2.062120e-02
# Sex.MIN(full.Age)                           2.062120e-02
# Sex.MIN(full.Fare)                          2.062120e-02
# Sex.MEAN(full.Age)                          2.062120e-02
# Sex.MEAN(full.Fare)                         2.062120e-02
# Sex.COUNT(full)                             2.062120e-02
# Sex.NUM_UNIQUE(full.Parch)                           NaN
# Sex.NUM_UNIQUE(full.Pclass)                          NaN
# Sex.NUM_UNIQUE(full.SibSp)                           NaN
# Sex.NUM_UNIQUE(full.Embarked)                        NaN
# Sex.MODE(full.Parch)                                 NaN
# Sex.MODE(full.Pclass)                                NaN
# Sex.MODE(full.SibSp)                                 NaN
# Sex.MODE(full.Embarked)                              NaN
# Pclass.SUM(full.Age)                        1.598170e-01
#
#                                   SibSp.MODE(full.Pclass)  \
# Age                                                   NaN
# Fare                                                  NaN
# Parch                                                 NaN
# Pclass                                                NaN
# SibSp                                                 NaN
# Embarked                                              NaN
# Sex                                                   NaN
# Embarked.SUM(full.Age)                                NaN
# Embarked.SUM(full.Fare)                               NaN
# Embarked.STD(full.Age)                                NaN
# Embarked.STD(full.Fare)                               NaN
# Embarked.MAX(full.Age)                                NaN
# Embarked.MAX(full.Fare)                               NaN
# Embarked.SKEW(full.Age)                               NaN
# Embarked.SKEW(full.Fare)                              NaN
# Embarked.MIN(full.Age)                                NaN
# Embarked.MIN(full.Fare)                               NaN
# Embarked.MEAN(full.Age)                               NaN
# Embarked.MEAN(full.Fare)                              NaN
# Embarked.COUNT(full)                                  NaN
# Embarked.NUM_UNIQUE(full.Parch)                       NaN
# Embarked.NUM_UNIQUE(full.Pclass)                      NaN
# Embarked.NUM_UNIQUE(full.SibSp)                       NaN
# Embarked.NUM_UNIQUE(full.Sex)                         NaN
# Embarked.MODE(full.Parch)                             NaN
# Embarked.MODE(full.Pclass)                            NaN
# Embarked.MODE(full.SibSp)                             NaN
# Embarked.MODE(full.Sex)                               NaN
# Sex.SUM(full.Age)                                     NaN
# Sex.SUM(full.Fare)                                    NaN
# Sex.STD(full.Age)                                     NaN
# Sex.STD(full.Fare)                                    NaN
# Sex.MAX(full.Age)                                     NaN
# Sex.MAX(full.Fare)                                    NaN
# Sex.SKEW(full.Age)                                    NaN
# Sex.SKEW(full.Fare)                                   NaN
# Sex.MIN(full.Age)                                     NaN
# Sex.MIN(full.Fare)                                    NaN
# Sex.MEAN(full.Age)                                    NaN
# Sex.MEAN(full.Fare)                                   NaN
# Sex.COUNT(full)                                       NaN
# Sex.NUM_UNIQUE(full.Parch)                            NaN
# Sex.NUM_UNIQUE(full.Pclass)                           NaN
# Sex.NUM_UNIQUE(full.SibSp)                            NaN
# Sex.NUM_UNIQUE(full.Embarked)                         NaN
# Sex.MODE(full.Parch)                                  NaN
# Sex.MODE(full.Pclass)                                 NaN
# Sex.MODE(full.SibSp)                                  NaN
# Sex.MODE(full.Embarked)                               NaN
# Pclass.SUM(full.Age)                                  NaN
#
#                                   SibSp.MODE(full.Embarked)  \
# Age                                                     NaN
# Fare                                                    NaN
# Parch                                                   NaN
# Pclass                                                  NaN
# SibSp                                                   NaN
# Embarked                                                NaN
# Sex                                                     NaN
# Embarked.SUM(full.Age)                                  NaN
# Embarked.SUM(full.Fare)                                 NaN
# Embarked.STD(full.Age)                                  NaN
# Embarked.STD(full.Fare)                                 NaN
# Embarked.MAX(full.Age)                                  NaN
# Embarked.MAX(full.Fare)                                 NaN
# Embarked.SKEW(full.Age)                                 NaN
# Embarked.SKEW(full.Fare)                                NaN
# Embarked.MIN(full.Age)                                  NaN
# Embarked.MIN(full.Fare)                                 NaN
# Embarked.MEAN(full.Age)                                 NaN
# Embarked.MEAN(full.Fare)                                NaN
# Embarked.COUNT(full)                                    NaN
# Embarked.NUM_UNIQUE(full.Parch)                         NaN
# Embarked.NUM_UNIQUE(full.Pclass)                        NaN
# Embarked.NUM_UNIQUE(full.SibSp)                         NaN
# Embarked.NUM_UNIQUE(full.Sex)                           NaN
# Embarked.MODE(full.Parch)                               NaN
# Embarked.MODE(full.Pclass)                              NaN
# Embarked.MODE(full.SibSp)                               NaN
# Embarked.MODE(full.Sex)                                 NaN
# Sex.SUM(full.Age)                                       NaN
# Sex.SUM(full.Fare)                                      NaN
# Sex.STD(full.Age)                                       NaN
# Sex.STD(full.Fare)                                      NaN
# Sex.MAX(full.Age)                                       NaN
# Sex.MAX(full.Fare)                                      NaN
# Sex.SKEW(full.Age)                                      NaN
# Sex.SKEW(full.Fare)                                     NaN
# Sex.MIN(full.Age)                                       NaN
# Sex.MIN(full.Fare)                                      NaN
# Sex.MEAN(full.Age)                                      NaN
# Sex.MEAN(full.Fare)                                     NaN
# Sex.COUNT(full)                                         NaN
# Sex.NUM_UNIQUE(full.Parch)                              NaN
# Sex.NUM_UNIQUE(full.Pclass)                             NaN
# Sex.NUM_UNIQUE(full.SibSp)                              NaN
# Sex.NUM_UNIQUE(full.Embarked)                           NaN
# Sex.MODE(full.Parch)                                    NaN
# Sex.MODE(full.Pclass)                                   NaN
# Sex.MODE(full.SibSp)                                    NaN
# Sex.MODE(full.Embarked)                                 NaN
# Pclass.SUM(full.Age)                                    NaN
#
#                                   SibSp.MODE(full.Sex)
# Age                                       2.282128e-02
# Fare                                      1.914642e-01
# Parch                                     2.488658e-01
# Pclass                                    1.623380e-01
# SibSp                                     3.515147e-01
# Embarked                                  4.370091e-02
# Sex                                       1.868998e-01
# Embarked.SUM(full.Age)                    1.143051e-02
# Embarked.SUM(full.Fare)                   6.454272e-02
# Embarked.STD(full.Age)                    1.220009e-01
# Embarked.STD(full.Fare)                   1.101666e-01
# Embarked.MAX(full.Age)                    2.605402e-03
# Embarked.MAX(full.Fare)                   1.170830e-01
# Embarked.SKEW(full.Age)                   1.151055e-01
# Embarked.SKEW(full.Fare)                  1.181705e-01
# Embarked.MIN(full.Age)                    9.299433e-02
# Embarked.MIN(full.Fare)                   3.181999e-02
# Embarked.MEAN(full.Age)                   1.024409e-01
# Embarked.MEAN(full.Fare)                  1.078349e-01
# Embarked.COUNT(full)                      8.577004e-03
# Embarked.NUM_UNIQUE(full.Parch)           6.475036e-03
# Embarked.NUM_UNIQUE(full.Pclass)                   NaN
# Embarked.NUM_UNIQUE(full.SibSp)           2.540821e-02
# Embarked.NUM_UNIQUE(full.Sex)                      NaN
# Embarked.MODE(full.Parch)                          NaN
# Embarked.MODE(full.Pclass)                8.529384e-02
# Embarked.MODE(full.SibSp)                          NaN
# Embarked.MODE(full.Sex)                            NaN
# Sex.SUM(full.Age)                         1.868998e-01
# Sex.SUM(full.Fare)                        1.868998e-01
# Sex.STD(full.Age)                         1.868998e-01
# Sex.STD(full.Fare)                        1.868998e-01
# Sex.MAX(full.Age)                         1.868998e-01
# Sex.MAX(full.Fare)                        2.207137e-16
# Sex.SKEW(full.Age)                        1.868998e-01
# Sex.SKEW(full.Fare)                       1.868998e-01
# Sex.MIN(full.Age)                         1.868998e-01
# Sex.MIN(full.Fare)                        1.868998e-01
# Sex.MEAN(full.Age)                        1.868998e-01
# Sex.MEAN(full.Fare)                       1.868998e-01
# Sex.COUNT(full)                           1.868998e-01
# Sex.NUM_UNIQUE(full.Parch)                         NaN
# Sex.NUM_UNIQUE(full.Pclass)                        NaN
# Sex.NUM_UNIQUE(full.SibSp)                         NaN
# Sex.NUM_UNIQUE(full.Embarked)                      NaN
# Sex.MODE(full.Parch)                               NaN
# Sex.MODE(full.Pclass)                              NaN
# Sex.MODE(full.SibSp)                               NaN
# Sex.MODE(full.Embarked)                            NaN
# Pclass.SUM(full.Age)                      1.314368e-01
#
# [50 rows x 112 columns]

# %%
collinear_features = [column for column in upper.columns if any(upper[column] > threshold)]

print('There are %d features to remove.' % (len(collinear_features)))
# Out:
# There are 48 features to remove.

# %%
features_filtered = features.drop(columns = collinear_features)

print('The number of features that passed the collinearity threshold: ', features_filtered.shape[1])
# Out:
# The number of features that passed the collinearity threshold:  64

# %% [markdown]
# ## Rapid XGBoost

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report

# %%
features_positive = features_filtered.loc[:, features_filtered.ge(0).all()]

# %%
features_positive
# Out:
#               Age      Fare  Parch  Pclass  SibSp  Embarked  Sex  \
# PassengerId
# 1            22.0    7.2500      0       3      1         0    1
# 2            38.0   71.2833      0       1      1         1    0
# 3            26.0    7.9250      0       3      0         0    0
# 4            35.0   53.1000      0       1      1         0    0
# 5            35.0    8.0500      0       3      0         0    1
# 6            28.0    8.4583      0       3      0         2    1
# 7            54.0   51.8625      0       1      0         0    1
# 8             2.0   21.0750      1       3      3         0    1
# 9            27.0   11.1333      2       3      0         0    0
# 10           14.0   30.0708      0       2      1         1    0
# 11            4.0   16.7000      1       3      1         0    0
# 12           58.0   26.5500      0       1      0         0    0
# 13           20.0    8.0500      0       3      0         0    1
# 14           39.0   31.2750      5       3      1         0    1
# 15           14.0    7.8542      0       3      0         0    0
# 16           55.0   16.0000      0       2      0         0    0
# 17            2.0   29.1250      1       3      4         2    1
# 18           28.0   13.0000      0       2      0         0    1
# 19           31.0   18.0000      0       3      1         0    0
# 20           28.0    7.2250      0       3      0         1    0
# 21           35.0   26.0000      0       2      0         0    1
# 22           34.0   13.0000      0       2      0         0    1
# 23           15.0    8.0292      0       3      0         2    0
# 24           28.0   35.5000      0       1      0         0    1
# 25            8.0   21.0750      1       3      3         0    0
# 26           38.0   31.3875      5       3      1         0    0
# 27           28.0    7.2250      0       3      0         1    1
# 28           19.0  263.0000      2       1      3         0    1
# 29           28.0    7.8792      0       3      0         2    0
# 30           28.0    7.8958      0       3      0         0    1
# ...           ...       ...    ...     ...    ...       ...  ...
# 1280         21.0    7.7500      0       3      0         2    1
# 1281          6.0   21.0750      1       3      3         0    1
# 1282         23.0   93.5000      0       1      0         0    1
# 1283         51.0   39.4000      1       1      0         0    0
# 1284         13.0   20.2500      2       3      0         0    1
# 1285         47.0   10.5000      0       2      0         0    1
# 1286         29.0   22.0250      1       3      3         0    1
# 1287         18.0   60.0000      0       1      1         0    0
# 1288         24.0    7.2500      0       3      0         2    1
# 1289         48.0   79.2000      1       1      1         1    0
# 1290         22.0    7.7750      0       3      0         0    1
# 1291         31.0    7.7333      0       3      0         2    1
# 1292         30.0  164.8667      0       1      0         0    0
# 1293         38.0   21.0000      0       2      1         0    1
# 1294         22.0   59.4000      1       1      0         1    0
# 1295         17.0   47.1000      0       1      0         0    1
# 1296         43.0   27.7208      0       1      1         1    1
# 1297         20.0   13.8625      0       2      0         1    1
# 1298         23.0   10.5000      0       2      1         0    1
# 1299         50.0  211.5000      1       1      1         1    1
# 1300         27.0    7.7208      0       3      0         2    0
# 1301          3.0   13.7750      1       3      1         0    0
# 1302         27.0    7.7500      0       3      0         2    0
# 1303         37.0   90.0000      0       1      1         2    0
# 1304         28.0    7.7750      0       3      0         0    0
# 1305         27.0    8.0500      0       3      0         0    1
# 1306         39.0  108.9000      0       1      0         1    0
# 1307         38.5    7.2500      0       3      0         0    1
# 1308         27.0    8.0500      0       3      0         0    1
# 1309         27.0   22.3583      1       3      1         1    1
#
#              Embarked.STD(full.Age)  Embarked.STD(full.Fare)  \
# PassengerId
# 1                         13.005236                37.076590
# 2                         13.632262                84.036802
# 3                         13.005236                37.076590
# 4                         13.005236                37.076590
# 5                         13.005236                37.076590
# 6                          9.991200                14.857148
# 7                         13.005236                37.076590
# 8                         13.005236                37.076590
# 9                         13.005236                37.076590
# 10                        13.632262                84.036802
# 11                        13.005236                37.076590
# 12                        13.005236                37.076590
# 13                        13.005236                37.076590
# 14                        13.005236                37.076590
# 15                        13.005236                37.076590
# 16                        13.005236                37.076590
# 17                         9.991200                14.857148
# 18                        13.005236                37.076590
# 19                        13.005236                37.076590
# 20                        13.632262                84.036802
# 21                        13.005236                37.076590
# 22                        13.005236                37.076590
# 23                         9.991200                14.857148
# 24                        13.005236                37.076590
# 25                        13.005236                37.076590
# 26                        13.005236                37.076590
# 27                        13.632262                84.036802
# 28                        13.005236                37.076590
# 29                         9.991200                14.857148
# 30                        13.005236                37.076590
# ...                             ...                      ...
# 1280                       9.991200                14.857148
# 1281                      13.005236                37.076590
# 1282                      13.005236                37.076590
# 1283                      13.005236                37.076590
# 1284                      13.005236                37.076590
# 1285                      13.005236                37.076590
# 1286                      13.005236                37.076590
# 1287                      13.005236                37.076590
# 1288                       9.991200                14.857148
# 1289                      13.632262                84.036802
# 1290                      13.005236                37.076590
# 1291                       9.991200                14.857148
# 1292                      13.005236                37.076590
# 1293                      13.005236                37.076590
# 1294                      13.632262                84.036802
# 1295                      13.005236                37.076590
# 1296                      13.632262                84.036802
# 1297                      13.632262                84.036802
# 1298                      13.005236                37.076590
# 1299                      13.632262                84.036802
# 1300                       9.991200                14.857148
# 1301                      13.005236                37.076590
# 1302                       9.991200                14.857148
# 1303                       9.991200                14.857148
# 1304                      13.005236                37.076590
# 1305                      13.005236                37.076590
# 1306                      13.632262                84.036802
# 1307                      13.005236                37.076590
# 1308                      13.005236                37.076590
# 1309                      13.632262                84.036802
#
#              Embarked.NUM_UNIQUE(full.Pclass)  ...  SibSp.MEAN(full.Age)  \
# PassengerId                                    ...
# 1                                           3  ...             30.643448
# 2                                           3  ...             30.643448
# 3                                           3  ...             30.168810
# 4                                           3  ...             30.643448
# 5                                           3  ...             30.168810
# 6                                           3  ...             30.168810
# 7                                           3  ...             30.168810
# 8                                           3  ...             18.650000
# 9                                           3  ...             30.168810
# 10                                          3  ...             30.643448
# 11                                          3  ...             30.643448
# 12                                          3  ...             30.168810
# 13                                          3  ...             30.168810
# 14                                          3  ...             30.643448
# 15                                          3  ...             30.168810
# 16                                          3  ...             30.168810
# 17                                          3  ...              8.772727
# 18                                          3  ...             30.168810
# 19                                          3  ...             30.643448
# 20                                          3  ...             30.168810
# 21                                          3  ...             30.168810
# 22                                          3  ...             30.168810
# 23                                          3  ...             30.168810
# 24                                          3  ...             30.168810
# 25                                          3  ...             18.650000
# 26                                          3  ...             30.643448
# 27                                          3  ...             30.168810
# 28                                          3  ...             18.650000
# 29                                          3  ...             30.168810
# 30                                          3  ...             30.168810
# ...                                       ...  ...                   ...
# 1280                                        3  ...             30.168810
# 1281                                        3  ...             18.650000
# 1282                                        3  ...             30.168810
# 1283                                        3  ...             30.168810
# 1284                                        3  ...             30.168810
# 1285                                        3  ...             30.168810
# 1286                                        3  ...             18.650000
# 1287                                        3  ...             30.643448
# 1288                                        3  ...             30.168810
# 1289                                        3  ...             30.643448
# 1290                                        3  ...             30.168810
# 1291                                        3  ...             30.168810
# 1292                                        3  ...             30.168810
# 1293                                        3  ...             30.643448
# 1294                                        3  ...             30.168810
# 1295                                        3  ...             30.168810
# 1296                                        3  ...             30.643448
# 1297                                        3  ...             30.168810
# 1298                                        3  ...             30.643448
# 1299                                        3  ...             30.643448
# 1300                                        3  ...             30.168810
# 1301                                        3  ...             30.643448
# 1302                                        3  ...             30.168810
# 1303                                        3  ...             30.643448
# 1304                                        3  ...             30.168810
# 1305                                        3  ...             30.168810
# 1306                                        3  ...             30.168810
# 1307                                        3  ...             30.168810
# 1308                                        3  ...             30.168810
# 1309                                        3  ...             30.643448
#
#              SibSp.MEAN(full.Fare)  SibSp.NUM_UNIQUE(full.Parch)  \
# PassengerId
# 1                        48.711300                             8
# 2                        48.711300                             8
# 3                        25.793835                             6
# 4                        48.711300                             8
# 5                        25.793835                             6
# 6                        25.793835                             6
# 7                        25.793835                             6
# 8                        71.332090                             3
# 9                        25.793835                             6
# 10                       48.711300                             8
# 11                       48.711300                             8
# 12                       25.793835                             6
# 13                       25.793835                             6
# 14                       48.711300                             8
# 15                       25.793835                             6
# 16                       25.793835                             6
# 17                       30.594318                             2
# 18                       25.793835                             6
# 19                       48.711300                             8
# 20                       25.793835                             6
# 21                       25.793835                             6
# 22                       25.793835                             6
# 23                       25.793835                             6
# 24                       25.793835                             6
# 25                       71.332090                             3
# 26                       48.711300                             8
# 27                       25.793835                             6
# 28                       71.332090                             3
# 29                       25.793835                             6
# 30                       25.793835                             6
# ...                            ...                           ...
# 1280                     25.793835                             6
# 1281                     71.332090                             3
# 1282                     25.793835                             6
# 1283                     25.793835                             6
# 1284                     25.793835                             6
# 1285                     25.793835                             6
# 1286                     71.332090                             3
# 1287                     48.711300                             8
# 1288                     25.793835                             6
# 1289                     48.711300                             8
# 1290                     25.793835                             6
# 1291                     25.793835                             6
# 1292                     25.793835                             6
# 1293                     48.711300                             8
# 1294                     25.793835                             6
# 1295                     25.793835                             6
# 1296                     48.711300                             8
# 1297                     25.793835                             6
# 1298                     48.711300                             8
# 1299                     48.711300                             8
# 1300                     25.793835                             6
# 1301                     48.711300                             8
# 1302                     25.793835                             6
# 1303                     48.711300                             8
# 1304                     25.793835                             6
# 1305                     25.793835                             6
# 1306                     25.793835                             6
# 1307                     25.793835                             6
# 1308                     25.793835                             6
# 1309                     48.711300                             8
#
#              SibSp.NUM_UNIQUE(full.Pclass)  SibSp.NUM_UNIQUE(full.Embarked)  \
# PassengerId
# 1                                        3                                3
# 2                                        3                                3
# 3                                        3                                3
# 4                                        3                                3
# 5                                        3                                3
# 6                                        3                                3
# 7                                        3                                3
# 8                                        3                                1
# 9                                        3                                3
# 10                                       3                                3
# 11                                       3                                3
# 12                                       3                                3
# 13                                       3                                3
# 14                                       3                                3
# 15                                       3                                3
# 16                                       3                                3
# 17                                       1                                2
# 18                                       3                                3
# 19                                       3                                3
# 20                                       3                                3
# 21                                       3                                3
# 22                                       3                                3
# 23                                       3                                3
# 24                                       3                                3
# 25                                       3                                1
# 26                                       3                                3
# 27                                       3                                3
# 28                                       3                                1
# 29                                       3                                3
# 30                                       3                                3
# ...                                    ...                              ...
# 1280                                     3                                3
# 1281                                     3                                1
# 1282                                     3                                3
# 1283                                     3                                3
# 1284                                     3                                3
# 1285                                     3                                3
# 1286                                     3                                1
# 1287                                     3                                3
# 1288                                     3                                3
# 1289                                     3                                3
# 1290                                     3                                3
# 1291                                     3                                3
# 1292                                     3                                3
# 1293                                     3                                3
# 1294                                     3                                3
# 1295                                     3                                3
# 1296                                     3                                3
# 1297                                     3                                3
# 1298                                     3                                3
# 1299                                     3                                3
# 1300                                     3                                3
# 1301                                     3                                3
# 1302                                     3                                3
# 1303                                     3                                3
# 1304                                     3                                3
# 1305                                     3                                3
# 1306                                     3                                3
# 1307                                     3                                3
# 1308                                     3                                3
# 1309                                     3                                3
#
#              SibSp.NUM_UNIQUE(full.Sex)  SibSp.MODE(full.Parch)  \
# PassengerId
# 1                                     2                       0
# 2                                     2                       0
# 3                                     2                       0
# 4                                     2                       0
# 5                                     2                       0
# 6                                     2                       0
# 7                                     2                       0
# 8                                     2                       1
# 9                                     2                       0
# 10                                    2                       0
# 11                                    2                       0
# 12                                    2                       0
# 13                                    2                       0
# 14                                    2                       0
# 15                                    2                       0
# 16                                    2                       0
# 17                                    2                       2
# 18                                    2                       0
# 19                                    2                       0
# 20                                    2                       0
# 21                                    2                       0
# 22                                    2                       0
# 23                                    2                       0
# 24                                    2                       0
# 25                                    2                       1
# 26                                    2                       0
# 27                                    2                       0
# 28                                    2                       1
# 29                                    2                       0
# 30                                    2                       0
# ...                                 ...                     ...
# 1280                                  2                       0
# 1281                                  2                       1
# 1282                                  2                       0
# 1283                                  2                       0
# 1284                                  2                       0
# 1285                                  2                       0
# 1286                                  2                       1
# 1287                                  2                       0
# 1288                                  2                       0
# 1289                                  2                       0
# 1290                                  2                       0
# 1291                                  2                       0
# 1292                                  2                       0
# 1293                                  2                       0
# 1294                                  2                       0
# 1295                                  2                       0
# 1296                                  2                       0
# 1297                                  2                       0
# 1298                                  2                       0
# 1299                                  2                       0
# 1300                                  2                       0
# 1301                                  2                       0
# 1302                                  2                       0
# 1303                                  2                       0
# 1304                                  2                       0
# 1305                                  2                       0
# 1306                                  2                       0
# 1307                                  2                       0
# 1308                                  2                       0
# 1309                                  2                       0
#
#              SibSp.MODE(full.Pclass)  SibSp.MODE(full.Embarked)  \
# PassengerId
# 1                                  3                          0
# 2                                  3                          0
# 3                                  3                          0
# 4                                  3                          0
# 5                                  3                          0
# 6                                  3                          0
# 7                                  3                          0
# 8                                  3                          0
# 9                                  3                          0
# 10                                 3                          0
# 11                                 3                          0
# 12                                 3                          0
# 13                                 3                          0
# 14                                 3                          0
# 15                                 3                          0
# 16                                 3                          0
# 17                                 3                          0
# 18                                 3                          0
# 19                                 3                          0
# 20                                 3                          0
# 21                                 3                          0
# 22                                 3                          0
# 23                                 3                          0
# 24                                 3                          0
# 25                                 3                          0
# 26                                 3                          0
# 27                                 3                          0
# 28                                 3                          0
# 29                                 3                          0
# 30                                 3                          0
# ...                              ...                        ...
# 1280                               3                          0
# 1281                               3                          0
# 1282                               3                          0
# 1283                               3                          0
# 1284                               3                          0
# 1285                               3                          0
# 1286                               3                          0
# 1287                               3                          0
# 1288                               3                          0
# 1289                               3                          0
# 1290                               3                          0
# 1291                               3                          0
# 1292                               3                          0
# 1293                               3                          0
# 1294                               3                          0
# 1295                               3                          0
# 1296                               3                          0
# 1297                               3                          0
# 1298                               3                          0
# 1299                               3                          0
# 1300                               3                          0
# 1301                               3                          0
# 1302                               3                          0
# 1303                               3                          0
# 1304                               3                          0
# 1305                               3                          0
# 1306                               3                          0
# 1307                               3                          0
# 1308                               3                          0
# 1309                               3                          0
#
#              SibSp.MODE(full.Sex)
# PassengerId
# 1                               0
# 2                               0
# 3                               1
# 4                               0
# 5                               1
# 6                               1
# 7                               1
# 8                               0
# 9                               1
# 10                              0
# 11                              0
# 12                              1
# 13                              1
# 14                              0
# 15                              1
# 16                              1
# 17                              1
# 18                              1
# 19                              0
# 20                              1
# 21                              1
# 22                              1
# 23                              1
# 24                              1
# 25                              0
# 26                              0
# 27                              1
# 28                              0
# 29                              1
# 30                              1
# ...                           ...
# 1280                            1
# 1281                            0
# 1282                            1
# 1283                            1
# 1284                            1
# 1285                            1
# 1286                            0
# 1287                            0
# 1288                            1
# 1289                            0
# 1290                            1
# 1291                            1
# 1292                            1
# 1293                            0
# 1294                            1
# 1295                            1
# 1296                            0
# 1297                            1
# 1298                            0
# 1299                            0
# 1300                            1
# 1301                            0
# 1302                            1
# 1303                            0
# 1304                            1
# 1305                            1
# 1306                            1
# 1307                            1
# 1308                            1
# 1309                            0
#
# [1309 rows x 63 columns]

# %%
train_X = features_positive[:train.shape[0]]
train_y = train['Survived']

test_X = features_positive[train.shape[0]:]

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_y, test_size=0.2, random_state=42)

# %%
gbm = xgb.XGBClassifier(max_depth=4, n_estimators=300, learning_rate=0.05, random_state=42)
gbm.fit(train_X, train_y)
cross_val_score(gbm,train_X, train_y, scoring='accuracy', cv=10).mean()
# Out:
# 0.8294841675178753

# %%
gbm_pred = gbm.predict(X_test)

# %%
print(classification_report(y_test, gbm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       105
#            1       0.89      0.85      0.87        74
#
#    micro avg       0.89      0.89      0.89       179
#    macro avg       0.89      0.89      0.89       179
# weighted avg       0.89      0.89      0.89       179

# %%
gbm_pred_final = gbm.predict(test_X)

# %% [markdown]
# ## Submission

# %%
sub = test_X.reset_index()

# %%
sub['Survived'] = pd.DataFrame(gbm_pred_final)

# %%
sub = sub[['PassengerId', 'Survived']]

# %%
sub.to_csv('gbm_submission.csv', index=False)
